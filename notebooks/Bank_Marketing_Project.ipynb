# %% [markdown]
# # Bank Term Deposit Prediction
#
# Machine Learning final project using the UCI Bank Marketing dataset.

# %% [markdown]
# ## Problem
# Predict whether a client will subscribe to a term deposit after a bank marketing campaign. This is a binary classification task.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
import matplotlib.pyplot as plt

from src.download_data import download_dataset

# %% [markdown]
# ## Load dataset

# %%
csv_path = download_dataset()
df = pd.read_csv(csv_path, sep=";")
df.head()

# %%
df.shape, df.columns.tolist()

# %% [markdown]
# ## EDA

# %%
df["y"].value_counts(normalize=True).round(3)

# %%
df["y"].value_counts().plot(kind="bar")
plt.title("Target Distribution")
plt.xlabel("Subscribed")
plt.ylabel("Count")
plt.show()

# %%
df.describe()

# %% [markdown]
# ## Train models

# %%
from src.train import main

# This runs the full pipeline: preprocessing, model training, evaluation, and saving outputs.
main()

# %% [markdown]
# ## Conclusion
# Compare the saved metrics in `outputs/metrics.json`. The best model is selected by ROC-AUC.
